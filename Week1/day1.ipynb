# %%
# Importing necessary libraries
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
print(api_key)
# Out:
# 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

# %%
# api key validation
if not api_key:
    print("API key not found, identify the issue and fix it")
elif not api_key.startswith("sk-"):
    print("Invalid API key")
elif api_key.strip() != api_key:
    print("API key contains leading or trailing whitespace")
else:
    print("API key is valid")
# Out:
# API key is valid

# %%
message = "please assist me to undestand what is the best way to learn AI"
messages = [{'role' : 'user','content': message}]
print(messages)
# Out:
# [{'role': 'user', 'content': 'please assist me to undestand what is the best way to learn AI'}]

# %%
openai = OpenAI()

response=openai.chat.completions.create(model="gpt-5-nano",messages=messages)
response.choices[0].message.content
# Out:
# 'Great question. There isn’t a single one-size-fits-all “best” path to learning AI, but there is a practical, adaptable plan that works for most people. Below is a structured approach you can tailor to your background, goals, and time.\n\n1) First, define your goal\n- Do you want to build AI features in software (ML engineering / applied AI)?\n- Do you want to do research (papers, novel methods)?\n- Do you want to be able to analyze data with ML (data science)?\n- Do you want to work with NLP, computer vision, robotics, or generative models?\nKnowing your goal helps you emphasize the right topics and projects.\n\n2) Build the foundation (math + programming)\n- Programming: Python (numpy, pandas). Get comfortable with reading docs, debugging, and git.\n- Math essentials (focus on intuition first, then depth as needed): linear algebra (vectors, matrices, eigenvalues), calculus basics (gradients, backprop), probability and statistics (distributions, Bayes, likelihoods), optimization (gradient descent, learning rate).\n- Practical starter resources:\n  - Python: Automate the Boring Stuff with Python, or any intro Python course.\n  - Math intuition: 3Blue1Brown videos on linear algebra and neural networks; Khan Academy for basics.\n  - Intro to ML concepts: Andrew Ng’s Machine Learning course (Coursera) or Google’s ML Crash Course.\n\n3) Core learning path (stage-by-stage)\nStage A — Foundational ML concepts (weeks to months depending on pace)\n- Topics: supervised/unsupervised learning, overfitting/underfitting, train/validation/test, bias-variance, evaluation metrics (accuracy, precision/recall, ROC-AUC), basics of optimization (gradient descent, learning rate).\n- Hands-on: implement linear regression, logistic regression and a basic classifier from scratch; move to scikit-learn for more practice.\n- Projects: Predict house prices, classify tabular data, baseline model comparison.\n\nStage B — Deep learning fundamentals\n- Topics: neural networks basics, backpropagation, activation functions, regularization, CNNs, RNNs/LSTMs, introduction to transformers.\n- Tools: PyTorch or TensorFlow (choose one; PyTorch is popular for beginners).\n- Courses/books:\n  - Fast.ai Practical Deep Learning (very hands-on, project-driven)\n  - Deep Learning Specialization (Coursera) or MIT/Stanford DL courses\n  - Books: “Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow” (Géron) for practical implementation; “Deep Learning” (Goodfellow, Bengio, Courville) for theory.\n- Projects: Image classifier on a small dataset, sentiment analysis with a simple LSTM, toy image generation with a basic GAN.\n\nStage C — Specialization area (choose NLP, CV, RL, or generative AI)\n- NLP: transformers, attention, fine-tuning BERT/GPT-like models, practical text generation.\n- Computer Vision: object detection, segmentation, vision transformers.\n- Reinforcement Learning: value functions, policy gradient, basic environments (OpenAI Gym, Atari).\n- Generative AI: diffusion models or large language models basics; responsible use and evaluation.\n- Courses/books depend on specialization (e.g., CS224n for NLP, CS231n for CV, Spinning Up for RL, Hugging Face tutorials for practical NLP models).\n\nStage D — ML engineering / deployment (optional but highly valuable)\n- Topics: data pipelines, model evaluation & monitoring, versioning, reproducibility, MLOps basics, serving models (FastAPI, TorchServe), cloud basics (AWS/GCP/Azure), experiments tracking (MLflow, Weights & Biases).\n- Projects: Deploy a small model as an API; set up CI/CD for ML; run a simple A/B test.\n\n4) Practical learning tips\n- Do it hands-on every step: code more than you read. Build small projects that you can show.\n- Alternate between theory and practice, but lean toward practice early to build intuition.\n- Use a project-based roadmap: a few guided projects first, then your own ideas.\n- Learn to read papers selectively: start with survey/tutorial papers or blog posts that disti ...

# %% [markdown]
# OK Onwards with our first project

# %%
from scraper import fetch_website_content
ed = fetch_website_content("https://campus.datacamp.com/courses/working-with-the-openai-api/introduction-to-the-openai-api?ex=1&skip_variants_modal=true")
print(ed)
# Out:
# What is the OpenAI API? | OpenAI Get started Get started for free Home Courses Working with the OpenAI API What is the OpenAI API? 1 . What is the OpenAI API? Welcome to the course! I'm James, and I'll be your host as we explore the artificial intelligence functionality available via the OpenAI API! 2 . Coming up... In this course, you'll learn how to use the AI models available through the OpenAI API to solve a wide range of real-world tasks. To do this, we'll be using Python code throughout the course, and expect familiarity with a few Python programming topics like subsetting lists and dictionaries, control flow, and looping. However, no experience with AI or machine learning is required. With that, let's dive in! 3 . OpenAI, ChatGPT, and the OpenAI API OpenAI is a company that researches and develops artificial intelligence systems. One of their most famous developments is ChatGPT, which is an application that allows users to communicate with an AI-powered chatbot to ask questions, perform tasks, or generate content. The OpenAI API allows individuals or organizations to access and customize any of the models developed and released by OpenAI. 4 . OpenAI, ChatGPT, and the OpenAI API If OpenAI was a car manufacturer, ChatGPT would be their shiny new sports car that people can walk into a dealership and test drive. 5 . OpenAI, ChatGPT, and the OpenAI API The OpenAI API would be like the system customers could use to customize and order cars from the manufacturer's catalog. 6 . What is an API? So what actually is an API? API stands for Application Programming Interface, and they act as messengers between software applications, taking a request to a system and receiving a response containing data or services. 7 . What is an API? APIs are like waiters in a restaurant; they take our order, or request, communicate it to the kitchen - the system providing the service - and finally, deliver the food, or response from the system, back to our table. 8 . What is an API? Many applications interact using APIs; for example, a mobile weather app may send our location to an API and request the local weather forecast, which is returned back to our phones. 9 . The OpenAI API Similarly, we can write code to interact with the OpenAI API and request the use of one of their models. 10 . The OpenAI API Our request, in this case, will specify which model we want, the data for the model to use, and any other parameters to customize the model's behavior. The response, containing the model result, is then returned. 11 . API vs. web interface Some of OpenAI's models can be used from the web browser, such as via ChatGPT. This low-setup browser experience is often sufficient for streamlining our workflows using AI. However, if we're looking to begin integrating AI into our products, customer experiences, and business processes, we'll need the flexibility of working with the models programmatically using an API. 12 . Building AI applications The OpenAI API has enabled the development of powerful new features, that before, would have required enormous computational resources and data. In this example, from DataLab-DataCamp's own AI-powered IDE-we developed a feature where you can use natural language to extract insights from data - all built on the OpenAI API! I highly recommend giving it a try! 13 . Let's practice! Time to test your understanding! Show Transcripts Create Your Free Account or Email Address Password Visible Start Learning for Free By continuing, you accept our Terms of Use , our Privacy Policy and that your data is stored in the USA. This exercise is part of the course Working with the OpenAI API Beginner Skill Level 4.8 + 5952 reviews Start Course for Free Chapter 1: Introduction to the OpenAI API Harness the power of AI from OpenAI's models by creating requests to their API with just a few lines of code. Discover the wide range of capabilities available via the OpenAI API. Exercise 1: What is the OpenAI API? Current Exercise Exercise 2: Ap ...
